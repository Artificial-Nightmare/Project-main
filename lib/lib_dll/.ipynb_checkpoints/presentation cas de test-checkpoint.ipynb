# %% [markdown]
# # CAS DE TEST

# %% [markdown]
# # TEST LINEAIRE

# %% [markdown]
# classification binaire simple SUCCES

# %%
import ctypes
import numpy as np
import os
import sys
import matplotlib.pyplot as plt

# Get the directory of the current script
current_dir = os.getcwd()

# Append the path to the DLL to the system's search path
dll_path = os.path.join(current_dir, 'liblinear_classification.dll')
sys.path.append(dll_path)
dll = ctypes.cdll.LoadLibrary(dll_path)

# Définition des types de données pour la fonction rosenblatt
dll.rosenblatt.argtypes = [np.ctypeslib.ndpointer(dtype=np.double, ndim=2, flags='C_CONTIGUOUS'),
                           np.ctypeslib.ndpointer(dtype=np.double, ndim=1, flags='C_CONTIGUOUS'),
                           ctypes.c_int, ctypes.c_int, ctypes.c_double, ctypes.c_int,
                           np.ctypeslib.ndpointer(dtype=np.double, ndim=1, flags='C_CONTIGUOUS'),
                           ctypes.c_int]

# Exemple d'utilisation
# n'oubliez pas de mettre le dtype=np.float64 !
X = np.array([
      [1, 1],
      [2, 3],
      [3, 3]
], dtype=np.float64)
Y = np.array([
      1,
      -1,
      -1
],dtype=np.float64).flatten()
learning_rate = 0.1
max_iterations = 100
# Centrage et réduction des données
X = (X - np.mean(X, axis=0)) / np.std(X, axis=0)

# Créer un tableau de sortie pour les poids entraînés
w = np.zeros((X.shape[1] + 1) * 2, dtype=np.float64)

# Appeler la fonction rosenblatt avec un pointeur vers le tableau de sortie
dll.rosenblatt(X, Y, X.shape[0], X.shape[1], learning_rate, max_iterations, w,2)

for i in range(2):  # Remplacez 2 par le nombre de classes que vous voulez
    print(f"Poids pour la classe {i} : {w[i*(X.shape[1] + 1):(i+1)*(X.shape[1] + 1)]}")

# Affichage des données
plt.scatter(X[0, 0], X[0, 1], color='blue')
plt.scatter(X[1:3,0], X[1:3,1], color='red')
# Affichage de la droite de séparation
x = np.linspace(-1, 4, 100)
for i in range(2):  # Remplacez 2 par le nombre de classes que vous voulez
    w_i = w[i*(X.shape[1] + 1):(i+1)*(X.shape[1] + 1)]
    y = -(w_i[0] * x + w_i[2]) / w_i[1]
    plt.plot(x, y, color='black')
plt.show()

# %% [markdown]
# classification binaire SUCCES

# %%
import ctypes
import numpy as np
import os
import sys
import matplotlib.pyplot as plt

# Get the directory of the current script
current_dir = os.getcwd()

# Append the path to the DLL to the system's search path
dll_path = os.path.join(current_dir, 'liblinear_classification.dll')
sys.path.append(dll_path)
dll = ctypes.cdll.LoadLibrary(dll_path)

# Définition des types de données pour la fonction rosenblatt
dll.rosenblatt.argtypes = [np.ctypeslib.ndpointer(dtype=np.double, ndim=2, flags='C_CONTIGUOUS'),
                           np.ctypeslib.ndpointer(dtype=np.double, ndim=1, flags='C_CONTIGUOUS'),
                           ctypes.c_int, ctypes.c_int, ctypes.c_double, ctypes.c_int,
                           np.ctypeslib.ndpointer(dtype=np.double, ndim=1, flags='C_CONTIGUOUS'),
                           ctypes.c_int]

# Exemple d'utilisation
# pas oublier de mettre le dtype=np.float64 !
X = np.concatenate([np.random.random((50,2)) * 1 + np.array([1, 1]), np.random.random((50,2)) * 1 + np.array([2, 2])], dtype=np.float64)
Y = np.concatenate([np.ones((50, 1)), np.ones((50, 1)) * -1.0], dtype=np.float64).flatten()
learning_rate = 0.1
max_iterations = 100
# Centrage et réduction des données
X = (X - np.mean(X, axis=0)) / np.std(X, axis=0)

# Créer un tableau de sortie pour les poids entraînés
w = np.zeros((X.shape[1] + 1) * 2, dtype=np.float64)  # Remplacez 2 par le nombre de classes que vous voulez

# Appeler la fonction rosenblatt avec un pointeur vers le tableau de sortie
dll.rosenblatt(X, Y, X.shape[0], X.shape[1], learning_rate, max_iterations, w, 2)  # Remplacez 2 par le nombre de classes que vous voulez

# Affichage des poids pour chaque classe
for i in range(2):  # Remplacez 2 par le nombre de classes que vous voulez
    print(f"Poids pour la classe {i} : {w[i*(X.shape[1] + 1):(i+1)*(X.shape[1] + 1)]}")

# Affichage des données
plt.scatter(X[0:50, 0], X[0:50, 1], color='blue')
plt.scatter(X[50:100,0], X[50:100,1], color='red') 

# Affichage de la droite de séparation

x = np.linspace(-2, 2, 100)
for i in range(2):  # Remplacez 2 par le nombre de classes que vous voulez
    w_i = w[i*(X.shape[1] + 1):(i+1)*(X.shape[1] + 1)]
    y = -(w_i[0] * x + w_i[2]) / w_i[1]
    plt.plot(x, y, color='black')

plt.show()

# %% [markdown]
# test multi class ECHEC

# %%
import ctypes
import numpy as np
import os
import sys
import matplotlib.pyplot as plt

# Get the directory of the current script
current_dir = os.getcwd()

# Append the path to the DLL to the system's search path
dll_path = os.path.join(current_dir, 'liblinear_classification.dll')
sys.path.append(dll_path)
dll = ctypes.cdll.LoadLibrary(dll_path)

# Définition des types de données pour la fonction rosenblatt
dll.rosenblatt.argtypes = [np.ctypeslib.ndpointer(dtype=np.double, ndim=2, flags='C_CONTIGUOUS'),
                           np.ctypeslib.ndpointer(dtype=np.double, ndim=1, flags='C_CONTIGUOUS'),
                           ctypes.c_int, ctypes.c_int, ctypes.c_double, ctypes.c_int,
                           np.ctypeslib.ndpointer(dtype=np.double, ndim=1, flags='C_CONTIGUOUS'),
                           ctypes.c_int]

# Exemple d'utilisation
# n'oubliez pas de mettre le dtype=np.float64 !
X = np.random.random((500, 2)) * 2.0 - 1.0
Y = np.array([[1, 0, 0] if -p[0] - p[1] - 0.5 > 0 and p[1] < 0 and p[0] - p[1] - 0.5 < 0 else 
              [0, 1, 0] if -p[0] - p[1] - 0.5 < 0 and p[1] > 0 and p[0] - p[1] - 0.5 < 0 else 
              [0, 0, 1] if -p[0] - p[1] - 0.5 < 0 and p[1] < 0 and p[0] - p[1] - 0.5 > 0 else 
              [0, 0, 0]for p in X], dtype=np.float64)

Xp = X.astype(np.float64)
Yp = Y.flatten().astype(np.float64)

learning_rate = 0.001
max_iterations = 20000
# Centrage et réduction des données
Xp = (Xp - np.mean(Xp, axis=0)) / np.std(Xp, axis=0)

# Créer un tableau de sortie pour les poids entraînés
w = np.zeros((Xp.shape[1] + 1) * 3, dtype=np.float64)  # Remplacez 3 par le nombre de classes que vous voulez

# Appeler la fonction rosenblatt avec un pointeur vers le tableau de sortie
dll.rosenblatt(Xp, Yp, Xp.shape[0], Xp.shape[1], learning_rate, max_iterations, w, 3)

for i in range(3):
    print(f"Poids pour la classe {i} : {w[i*(Xp.shape[1] + 1):(i+1)*(Xp.shape[1] + 1)]}")

plt.scatter(X[Y[:, 0] == 1, 0], X[Y[:, 0] == 1, 1], color='blue')
plt.scatter(X[Y[:, 1] == 1, 0], X[Y[:, 1] == 1, 1], color='red')
plt.scatter(X[Y[:, 2] == 1, 0], X[Y[:, 2] == 1, 1], color='green')

# Affichage des droites de séparation
x = np.linspace(-2, 2, 100)
for i in range(3):
    w_i = w[i*(Xp.shape[1] + 1):(i+1)*(Xp.shape[1] + 1)]
    y = -(w_i[0] * x + w_i[2]) / w_i[1]
    plt.plot(x, y, color='black')

plt.show()

# %% [markdown]
# # TEST PMC

# %% [markdown]
# probleme de XOR SUCCES

# %%
import ctypes
import numpy as np
import os
import sys

# Get the directory of the current script
current_dir = os.getcwd()

# Append the path to the DLL to the system's search path
dll_path = os.path.join(current_dir, 'perceptron_multi_couche.dll')
sys.path.append(dll_path)

# Load the DLL
mlp_dll = ctypes.cdll.LoadLibrary(dll_path)

# Définition des types de données
mlp_dll.createMLP.restype = ctypes.c_void_p
mlp_dll.createMLP.argtypes = [ctypes.POINTER(ctypes.c_int), ctypes.c_int]
mlp_dll.deleteMLP.argtypes = [ctypes.c_void_p]
mlp_dll.predict.argtypes = [ctypes.c_void_p, ctypes.POINTER(ctypes.c_double), ctypes.c_int, ctypes.c_bool, ctypes.POINTER(ctypes.c_double), ctypes.c_int]
mlp_dll.train.argtypes = [ctypes.c_void_p, ctypes.POINTER(ctypes.c_double), ctypes.POINTER(ctypes.c_double), ctypes.c_int, ctypes.c_int, ctypes.c_int, ctypes.c_bool, ctypes.c_int, ctypes.c_double]

# Création du MLP avec 2 entrées, 2 neurones cachés et 1 sortie
npl = np.array([2,2, 1], dtype=np.int32)
mlp_ptr = mlp_dll.createMLP(npl.ctypes.data_as(ctypes.POINTER(ctypes.c_int)), npl.size)

# Entraînement du MLP sur le XOR
samples_inputs = np.array([[0, 0], [0, 1], [1, 0], [1, 1]], dtype=np.double)
samples_expected_outputs = np.array([[0], [1], [1], [0]], dtype=np.double)
mlp_dll.train(mlp_ptr,
               samples_inputs.ctypes.data_as(ctypes.POINTER(ctypes.c_double)),
               samples_expected_outputs.ctypes.data_as(ctypes.POINTER(ctypes.c_double)),
               samples_inputs.shape[0], samples_inputs.shape[1], samples_expected_outputs.shape[1],
               True,400000, 0.01)

# Test du MLP sur le XOR
input = np.zeros(2, dtype=np.double)
output = np.zeros(1, dtype=np.double)
for i in range(samples_inputs.shape[0]):
    input[0] = samples_inputs[i, 0]
    input[1] = samples_inputs[i, 1]
    mlp_dll.predict(mlp_ptr, 
                    input.ctypes.data_as(ctypes.POINTER(ctypes.c_double)), 
                    input.size, 
                    True, 
                    output.ctypes.data_as(ctypes.POINTER(ctypes.c_double)), 
                    output.size)
    print(f"[{int(input[0])}, {int(input[1])}] = {output[0]}")

# Suppression du MLP
mlp_dll.deleteMLP(mlp_ptr)

# %% [markdown]
# test corss classification SUCCES ??

# %%
import ctypes
import numpy as np
import os
import sys

# Get the directory of the current script
current_dir = os.getcwd()

# Append the path to the DLL to the system's search path
dll_path = os.path.join(current_dir, 'perceptron_multi_couche.dll')
sys.path.append(dll_path)

# Load the DLL
mlp_dll = ctypes.cdll.LoadLibrary(dll_path)

# Définition des types de données
mlp_dll.createMLP.restype = ctypes.c_void_p
mlp_dll.createMLP.argtypes = [ctypes.POINTER(ctypes.c_int), ctypes.c_int]
mlp_dll.deleteMLP.argtypes = [ctypes.c_void_p]
mlp_dll.predict.argtypes = [ctypes.c_void_p, ctypes.POINTER(ctypes.c_double), ctypes.c_int, ctypes.c_bool, ctypes.POINTER(ctypes.c_double), ctypes.c_int]
mlp_dll.train.argtypes = [ctypes.c_void_p, ctypes.POINTER(ctypes.c_double), ctypes.POINTER(ctypes.c_double), ctypes.c_int, ctypes.c_int, ctypes.c_int, ctypes.c_bool, ctypes.c_int, ctypes.c_double]

# Création du MLP avec 2 entrées, 2 neurones cachés et 1 sortie
npl = np.array([2,4, 1], dtype=np.int32)
mlp_ptr = mlp_dll.createMLP(npl.ctypes.data_as(ctypes.POINTER(ctypes.c_int)), npl.size)

X = np.random.random((500, 2)) * 2.0 - 1.0
samples_inputs = np.array(X, dtype=np.double)
Y = np.array([1 if abs(p[0]) <= 0.3 or abs(p[1]) <= 0.3 else -1 for p in X])
samples_expected_outputs = np.array(Y, dtype=np.double)
mlp_dll.train(mlp_ptr,
               samples_inputs.ctypes.data_as(ctypes.POINTER(ctypes.c_double)),
               samples_expected_outputs.ctypes.data_as(ctypes.POINTER(ctypes.c_double)),
               samples_inputs.shape[0], samples_inputs.shape[1], 1,
               True, 2500000, 0.2)


input_size = 2
output_size = 1

input = np.zeros(input_size, dtype=np.double)
output = np.zeros(output_size, dtype=np.double)

correct_predictions = 0

for i in range(samples_inputs.shape[0]):
    input[0] = samples_inputs[i, 0]
    input[1] = samples_inputs[i, 1]
    mlp_dll.predict(mlp_ptr, 
                    input.ctypes.data_as(ctypes.POINTER(ctypes.c_double)), 
                    input.size, 
                    True, 
                    output.ctypes.data_as(ctypes.POINTER(ctypes.c_double)), 
                    output.size)
    expected_class = int(samples_expected_outputs[i])
    predicted_class = 1 if output[0] >= 0.5 else -1
    print(f"[{input[0]}, {input[1]}] Expected Class: {expected_class}, Predicted Class: {predicted_class}")
    
    if expected_class == predicted_class:
        correct_predictions += 1

accuracy = (correct_predictions / samples_inputs.shape[0]) * 100
print(f"\nAccuracy: {accuracy}%")





# Suppression du MLP
mlp_dll.deleteMLP(mlp_ptr)

# %% [markdown]
# test multi cross a voir

# %%
import ctypes
import numpy as np
import os
import sys

# Get the directory of the current script
current_dir = os.getcwd()

# Append the path to the DLL to the system's search path
dll_path = os.path.join(current_dir, 'perceptron_multi_couche.dll')
sys.path.append(dll_path)

# Load the DLL
mlp_dll = ctypes.cdll.LoadLibrary(dll_path)

# Définition des types de données
mlp_dll.createMLP.restype = ctypes.c_void_p
mlp_dll.createMLP.argtypes = [ctypes.POINTER(ctypes.c_int), ctypes.c_int]
mlp_dll.deleteMLP.argtypes = [ctypes.c_void_p]
mlp_dll.predict.argtypes = [ctypes.c_void_p, ctypes.POINTER(ctypes.c_double), ctypes.c_int, ctypes.c_bool, ctypes.POINTER(ctypes.c_double), ctypes.c_int]
mlp_dll.train.argtypes = [ctypes.c_void_p, ctypes.POINTER(ctypes.c_double), ctypes.POINTER(ctypes.c_double), ctypes.c_int, ctypes.c_int, ctypes.c_int, ctypes.c_bool, ctypes.c_int, ctypes.c_double]

# Création du MLP avec 2 entrées, 2 neurones cachés et 1 sortie
npl = np.array([2,128,64, 3], dtype=np.int32)
mlp_ptr = mlp_dll.createMLP(npl.ctypes.data_as(ctypes.POINTER(ctypes.c_int)), npl.size)

X = np.random.random((1000, 2)) * 2.0 - 1.0
samples_inputs = np.array(X, dtype=np.double)
Y = np.array([[1, 0, 0] if abs(p[0] % 0.5) <= 0.25 and abs(p[1] % 0.5) > 0.25 else [0, 1, 0] if abs(p[0] % 0.5) > 0.25 and abs(p[1] % 0.5) <= 0.25 else [0, 0, 1] for p in X])
samples_expected_outputs = np.array(Y, dtype=np.double)
mlp_dll.train(mlp_ptr,
               samples_inputs.ctypes.data_as(ctypes.POINTER(ctypes.c_double)),
               samples_expected_outputs.ctypes.data_as(ctypes.POINTER(ctypes.c_double)),
               samples_inputs.shape[0], samples_inputs.shape[1], 1,
               True, 500000, 0.0000002)

correct_predictions = 0
total_predictions = samples_inputs.shape[0]
# Utilisation de la fonction "predict" pour prédire les sorties pour chaque entrée
for i in range(samples_inputs.shape[0]):
    input = samples_inputs[i]
    output = np.zeros(samples_expected_outputs.shape[1], dtype=np.double)

    mlp_dll.predict(mlp_ptr, 
                    input.ctypes.data_as(ctypes.POINTER(ctypes.c_double)), 
                    input.size, 
                    True, 
                    output.ctypes.data_as(ctypes.POINTER(ctypes.c_double)), 
                    output.size)

    predicted_label = np.argmax(output)
    expected_label = np.argmax(samples_expected_outputs[i])

    print("Entrée :", input)
    print("Sortie prédite :", output)
    print("Sortie attendue :", samples_expected_outputs[i])

    if predicted_label == expected_label:
        correct_predictions += 1

    print()

accuracy = correct_predictions / total_predictions
print("Taux de réussite : {:.2%}".format(accuracy))     

# Suppression du MLP
mlp_dll.deleteMLP(mlp_ptr)
# Out:
# Entrée : [0.01194186 0.13347979]
# Sortie prédite : [0.01426202 0.99999829 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.486348   -0.01948388]
# Sortie prédite : [0.02204357 0.9999972  1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [-0.724606   -0.01264681]
# Sortie prédite : [0.02704972 0.99999659 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [0.40931018 0.11173689]
# Sortie prédite : [0.00996175 0.99999852 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [-0.22167493  0.19112727]
# Sortie prédite : [0.01784821 0.99999812 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [-0.97394509  0.26787982]
# Sortie prédite : [0.03600983 0.99999686 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [ 0.19492871 -0.49900004]
# Sortie prédite : [0.01165144 0.99999737 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [ 0.25824267 -0.30976107]
# Sortie prédite : [0.01122917 0.9999979  1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [-0.35909444 -0.13704952]
# Sortie prédite : [0.01922012 0.99999717 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [-0.63222454  0.87592832]
# Sortie prédite : [0.02706921 0.99999847 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.16193892  0.15378505]
# Sortie prédite : [0.0168017  0.99999814 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [0.71972394 0.34859291]
# Sortie prédite : [0.00746223 0.99999865 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [ 0.79156709 -0.15133543]
# Sortie prédite : [0.00738541 0.99999843 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [ 0.34653139 -0.94231948]
# Sortie prédite : [0.01016055 0.99999615 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [-0.29760627 -0.2287162 ]
# Sortie prédite : [0.01789472 0.99999704 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [0.03437628 0.44603545]
# Sortie prédite : [0.01418546 0.99999858 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [-0.8008131  -0.07151799]
# Sortie prédite : [0.02815079 0.99999612 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [-0.70057525  0.80970884]
# Sortie prédite : [0.02911736 0.99999836 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.07381311  0.09674505]
# Sortie prédite : [0.01539071 0.99999816 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [-0.07143851  0.36294135]
# Sortie prédite : [0.01565871 0.99999846 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.09635561  0.69964409]
# Sortie prédite : [0.01617243 0.99999865 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [ 0.47599522 -0.96073584]
# Sortie prédite : [0.00936907 0.99999641 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [0.28495103 0.26581202]
# Sortie prédite : [0.01114052 0.99999857 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.3686757   0.30425152]
# Sortie prédite : [0.02080763 0.99999811 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [ 0.20091203 -0.27430584]
# Sortie prédite : [0.01177917 0.99999789 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [0.87492906 0.0746132 ]
# Sortie prédite : [0.00674921 0.99999856 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [0.63167899 0.8857493 ]
# Sortie prédite : [0.00787048 0.99999869 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [0.93629085 0.52696906]
# Sortie prédite : [0.00607094 0.99999864 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [ 0.84518446 -0.16104457]
# Sortie prédite : [0.00710401 0.99999843 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.05721454 -0.72548864]
# Sortie prédite : [0.01354151 0.99999585 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.71173658  0.50077165]
# Sortie prédite : [0.02954837 0.99999795 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [0.65841115 0.28442117]
# Sortie prédite : [0.00792173 0.99999864 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [-0.27316469 -0.98950038]
# Sortie prédite : [0.01443103 0.9999933  1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.02241227  0.05889879]
# Sortie prédite : [0.01463279 0.99999816 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [-0.10740313 -0.1398101 ]
# Sortie prédite : [0.01545    0.99999769 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.41069335  0.03413606]
# Sortie prédite : [0.02083062 0.99999752 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [0.74246773 0.99018151]
# Sortie prédite : [0.00707596 0.99999865 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [-0.8821598 -0.4432315]
# Sortie prédite : [0.02527881 0.9999938  1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.64724314 -0.59494091]
# Sortie prédite : [0.0204371 0.999994  1.       ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [0.21050764 0.92775428]
# Sortie prédite : [0.01188502 0.99999874 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [ 0.1132617  -0.18396396]
# Sortie prédite : [0.01273861 0.99999794 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [ 0.44753614 -0.24343709]
# Sortie prédite : [0.00968201 0.99999819 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [ 0.89157839 -0.36611392]
# Sortie prédite : [0.00703099 0.99999826 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [-0.5687192  -0.74087112]
# Sortie prédite : [0.0184055  0.99999344 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [0.30936425 0.82556227]
# Sortie prédite : [0.01081399 0.99999873 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.97960256 -0.21813859]
# Sortie prédite : [0.030031   0.99999472 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [-0.11583552  0.63813655]
# Sortie prédite : [0.01648807 0.99999862 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [-0.35328068 -0.1792325 ]
# Sortie prédite : [0.01894927 0.99999706 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [-0.29818521  0.35618877]
# Sortie prédite : [0.0195118  0.99999826 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [-0.89713069 -0.86066776]
# Sortie prédite : [0.02080511 0.99999044 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.71588829 -0.37657464]
# Sortie prédite : [0.02341321 0.99999497 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [-0.04432586  0.90079593]
# Sortie prédite : [0.01527314 0.99999872 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [0.55358268 0.68444251]
# Sortie prédite : [0.00853993 0.99999871 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.45251293 -0.22498092]
# Sortie prédite : [0.02033044 0.99999662 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [0.50788946 0.47364848]
# Sortie prédite : [0.00899926 0.99999869 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [ 0.25405371 -0.55380921]
# Sortie prédite : [0.0111079  0.99999733 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [0.31822027 0.23477295]
# Sortie prédite : [0.01080304 0.99999856 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [-0.56624538 -0.86889718]
# Sortie prédite : [0.01748381 0.99999253 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [-0.30922134 -0.77245712]
# Sortie prédite : [0.01568593 0.99999455 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.17585112  0.94232287]
# Sortie prédite : [0.01730322 0.9999987  1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.59617738  0.3517379 ]
# Sortie prédite : [0.02608387 0.99999786 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.3294543  -0.28921838]
# Sortie prédite : [0.01811836 0.99999676 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [0.20924207 0.7592307 ]
# Sortie prédite : [0.01195977 0.99999873 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [ 0.43829012 -0.83209229]
# Sortie prédite : [0.00963918 0.99999682 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [0.25766025 0.47810484]
# Sortie prédite : [0.01143766 0.99999866 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.31975648  0.23727222]
# Sortie prédite : [0.01970522 0.99999807 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.46213082  0.80857054]
# Sortie prédite : [0.02305642 0.99999854 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [-0.17490659  0.78950902]
# Sortie prédite : [0.01743159 0.99999866 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [0.08846756 0.59985367]
# Sortie prédite : [0.01349123 0.99999867 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [ 0.35503036 -0.12051503]
# Sortie prédite : [0.01043985 0.99999827 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.9897826  -0.07736092]
# Sortie prédite : [0.03225419 0.99999542 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [-0.05603235 -0.98227451]
# Sortie prédite : [0.01286206 0.99999443 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [-0.07821928 -0.08347599]
# Sortie prédite : [0.01516564 0.99999785 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [0.78897518 0.27049572]
# Sortie prédite : [0.00707742 0.99999863 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.87876836  0.99978506]
# Sortie prédite : [0.03374105 0.99999836 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [0.0573397  0.05017563]
# Sortie prédite : [0.01360405 0.99999823 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.94106758 -0.54668064]
# Sortie prédite : [0.02487693 0.99999276 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [ 0.44694693 -0.05636016]
# Sortie prédite : [0.00966987 0.9999984  1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [ 0.23384034 -0.89750375]
# Sortie prédite : [0.01094638 0.99999601 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.82264868 -0.90217304]
# Sortie prédite : [0.01964391 0.99999059 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.31338841  0.23851285]
# Sortie prédite : [0.01958732 0.99999808 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.36108711  0.69619487]
# Sortie prédite : [0.02097612 0.99999853 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.2870479  -0.80827374]
# Sortie prédite : [0.01532304 0.99999444 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [ 0.32980976 -0.64373393]
# Sortie prédite : [0.01046319 0.99999721 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [ 0.01475501 -0.30044519]
# Sortie prédite : [0.01367077 0.99999754 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [ 0.588006   -0.12007412]
# Sortie prédite : [0.00863288 0.9999984  1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [-0.428457   -0.94730108]
# Sortie prédite : [0.01583321 0.99999274 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.96739721 -0.03356761]
# Sortie prédite : [0.03234066 0.99999571 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [ 0.54072587 -0.29219467]
# Sortie prédite : [0.00901205 0.99999819 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.37362315 -0.35193871]
# Sortie prédite : [0.01846163 0.99999639 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [0.65018399 0.73758906]
# Sortie prédite : [0.00776535 0.9999987  1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.3753484   0.94888761]
# Sortie prédite : [0.02095101 0.99999865 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [0.12108108 0.12265799]
# Sortie prédite : [0.01289692 0.99999837 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.69846342 -0.34054134]
# Sortie prédite : [0.02348619 0.99999523 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [-0.0274351 -0.7548511]
# Sortie prédite : [0.01320863 0.99999582 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [ 0.69937188 -0.64714939]
# Sortie prédite : [0.00813336 0.99999772 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [-0.46681946  0.16490644]
# Sortie prédite : [0.02245546 0.99999771 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.32808324  0.91217887]
# Sortie prédite : [0.02008573 0.99999865 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [0.44975155 0.59241465]
# Sortie prédite : [0.00947578 0.99999871 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [-0.47436048 -0.42829402]
# Sortie prédite : [0.01943682 0.99999569 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [ 0.2049678  -0.93654178]
# Sortie prédite : [0.01110046 0.99999573 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.71195806 -0.33620041]
# Sortie prédite : [0.02374846 0.9999952  1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [0.6046322  0.08827619]
# Sortie prédite : [0.00841712 0.99999855 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [0.78788699 0.61311668]
# Sortie prédite : [0.00687055 0.99999867 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [-0.01797699 -0.17525491]
# Sortie prédite : [0.01424588 0.99999776 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [ 0.84934966 -0.01529198]
# Sortie prédite : [0.00696269 0.99999852 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [ 0.36736272 -0.33588654]
# Sortie prédite : [0.01029844 0.99999798 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [-0.89474448 -0.91621997]
# Sortie prédite : [0.02025123 0.99998994 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [ 0.26438071 -0.71480484]
# Sortie prédite : [0.01090018 0.99999684 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.07269668 -0.26903233]
# Sortie prédite : [0.01474518 0.99999745 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [0.39626288 0.5643751 ]
# Sortie prédite : [0.00998881 0.9999987  1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [ 0.37939821 -0.4032057 ]
# Sortie prédite : [0.01018725 0.99999787 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [ 0.71904998 -0.66170635]
# Sortie prédite : [0.00803441 0.99999771 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [0.49639311 0.93945391]
# Sortie prédite : [0.00896624 0.99999871 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [0.05241823 0.1210193 ]
# Sortie prédite : [0.01372969 0.99999831 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.97659834  0.96343836]
# Sortie prédite : [0.03722439 0.99999823 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [-0.53144642 -0.17716759]
# Sortie prédite : [0.02196406 0.99999656 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.7664533  -0.53867104]
# Sortie prédite : [0.02250777 0.99999376 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [-0.76587274 -0.28684819]
# Sortie prédite : [0.02516809 0.99999524 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.72046811  0.41652697]
# Sortie prédite : [0.02958342 0.99999778 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.23499898  0.17303996]
# Sortie prédite : [0.01804074 0.99999808 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [-0.87974382  0.73997439]
# Sortie prédite : [0.03477319 0.99999808 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.33954354  0.71243461]
# Sortie prédite : [0.02052876 0.99999855 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [ 0.65953344 -0.19657048]
# Sortie prédite : [0.00819536 0.99999836 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [-0.80647904  0.88726368]
# Sortie prédite : [0.03201442 0.99999833 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [-0.27177032 -0.79201872]
# Sortie prédite : [0.01525612 0.99999461 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.57196695 -0.63932434]
# Sortie prédite : [0.01918889 0.9999941  1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.37157751  0.46839515]
# Sortie prédite : [0.02112369 0.99999832 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [ 0.20219957 -0.90191424]
# Sortie prédite : [0.01116196 0.99999589 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.93847431  0.24620398]
# Sortie prédite : [0.03479269 0.99999688 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.6784795  -0.45690885]
# Sortie prédite : [0.02208146 0.99999469 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [-0.39824681 -0.25798298]
# Sortie prédite : [0.01929281 0.99999667 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [0.94823413 0.515401  ]
# Sortie prédite : [0.00601702 0.99999864 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [-0.98788757 -0.00889227]
# Sortie prédite : [0.0331546  0.99999575 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [0.66725901 0.72572138]
# Sortie prédite : [0.00764342 0.99999869 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.94452293 -0.57352055]
# Sortie prédite : [0.02459019 0.99999254 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [-0.81944596  0.0050476 ]
# Sortie prédite : [0.02935936 0.99999637 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.94746229  0.17545727]
# Sortie prédite : [0.03435069 0.99999662 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [0.26275662 0.44126779]
# Sortie prédite : [0.01138216 0.99999865 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [ 0.3386285  -0.78690999]
# Sortie prédite : [0.01031495 0.99999676 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [-0.30910757 -0.77171706]
# Sortie prédite : [0.01568827 0.99999456 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [ 0.98464768 -0.59303359]
# Sortie prédite : [0.00679268 0.999998   1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.57051622 -0.15172878]
# Sortie prédite : [0.02284228 0.99999654 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [0.97703231 0.64575822]
# Sortie prédite : [0.00580183 0.99999863 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [ 0.10108671 -0.40353973]
# Sortie prédite : [0.01262398 0.99999744 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.03670073 -0.07105914]
# Sortie prédite : [0.01464058 0.99999794 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [0.08958692 0.34426008]
# Sortie prédite : [0.01340805 0.99999854 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [ 0.55544203 -0.81614482]
# Sortie prédite : [0.00894131 0.9999971  1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.55056476  0.61851696]
# Sortie prédite : [0.02531853 0.99999831 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [ 0.38271877 -0.70733473]
# Sortie prédite : [0.01005457 0.99999712 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.58544393 -0.47942101]
# Sortie prédite : [0.02059114 0.99999498 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [-0.79396048 -0.04685702]
# Sortie prédite : [0.0282561  0.99999624 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [-0.55630548 -0.07037422]
# Sortie prédite : [0.02311647 0.99999687 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.97856689 -0.64653911]
# Sortie prédite : [0.02416084 0.99999176 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [-0.32651499 -0.14269445]
# Sortie prédite : [0.01866802 0.99999723 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [ 0.68257459 -0.52485785]
# Sortie prédite : [0.00819039 0.99999794 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [0.75732271 0.76867174]
# Sortie prédite : [0.00700902 0.99999867 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.12703987  0.91946355]
# Sortie prédite : [0.01653228 0.99999871 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.31298831 -0.30457068]
# Sortie prédite : [0.01781778 0.99999675 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.76050675 -0.35759561]
# Sortie prédite : [0.0243228  0.99999488 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.51680584  0.2353206 ]
# Sortie prédite : [0.02380364 0.99999777 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [-0.79984577  0.23064433]
# Sortie prédite : [0.03083313 0.99999718 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.34280198 -0.16475372]
# Sortie prédite : [0.01884194 0.99999713 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [-0.4677703   0.63998218]
# Sortie prédite : [0.02332487 0.99999841 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.10589789  0.09749428]
# Sortie prédite : [0.01585539 0.99999812 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [-0.7740874  -0.03026989]
# Sortie prédite : [0.0279822  0.99999637 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [-0.88814094  0.98014897]
# Sortie prédite : [0.03415692 0.99999833 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [-0.2552555   0.19322116]
# Sortie prédite : [0.01843308 0.99999809 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.12208121  0.23681742]
# Sortie prédite : [0.01630067 0.99999829 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [-0.39409364  0.71591691]
# Sortie prédite : [0.02165875 0.99999852 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [0.22040829 0.23813821]
# Sortie prédite : [0.01182188 0.99999853 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.33544304  0.66473661]
# Sortie prédite : [0.02046212 0.99999852 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.41882771  0.80854513]
# Sortie prédite : [0.02210032 0.99999856 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [ 0.20795075 -0.71339146]
# Sortie prédite : [0.01133293 0.99999671 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [0.05081787 0.73068361]
# Sortie prédite : [0.01399011 0.9999987  1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.56430346  0.12637688]
# Sortie prédite : [0.02440975 0.99999743 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [0.69668616 0.29745753]
# Sortie prédite : [0.00764951 0.99999864 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [-0.23952292  0.84410132]
# Sortie prédite : [0.01852003 0.99999866 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.02826849 -0.34850515]
# Sortie prédite : [0.01407133 0.99999733 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [ 0.53133028 -0.52139139]
# Sortie prédite : [0.00909999 0.99999781 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [-0.90616698  0.51358869]
# Sortie prédite : [0.03546882 0.99999765 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.60273228  0.50876996]
# Sortie prédite : [0.02658869 0.99999811 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [ 0.32423985 -0.40470515]
# Sortie prédite : [0.01062311 0.9999978  1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [ 0.6091868  -0.00954338]
# Sortie prédite : [0.00843536 0.99999849 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [-0.30254206  0.44135243]
# Sortie prédite : [0.01970518 0.99999835 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [ 0.95394408 -0.82661519]
# Sortie prédite : [0.00705358 0.99999756 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [-0.39973893 -0.08302038]
# Sortie prédite : [0.02014217 0.99999723 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [-0.18838509  0.32748248]
# Sortie prédite : [0.0174949  0.99999833 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.37117702  0.41571447]
# Sortie prédite : [0.02105123 0.99999826 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [0.36701394 0.64556595]
# Sortie prédite : [0.01025901 0.99999872 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [ 0.70301603 -0.5487711 ]
# Sortie prédite : [0.00808526 0.99999791 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [ 0.82303921 -0.02227214]
# Sortie prédite : [0.00711169 0.99999852 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [ 0.24268036 -0.47699699]
# Sortie prédite : [0.01125874 0.99999751 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.92768506  0.08401117]
# Sortie prédite : [0.03283264 0.99999634 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.28717109 -0.37393954]
# Sortie prédite : [0.0171816  0.99999657 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [ 0.99815641 -0.83232036]
# Sortie prédite : [0.00689353 0.99999758 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [-0.8893871  -0.12755836]
# Sortie prédite : [0.02939712 0.99999555 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [ 0.59353958 -0.1297827 ]
# Sortie prédite : [0.00859879 0.99999839 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [0.95947496 0.06515322]
# Sortie prédite : [0.00633262 0.99999855 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [0.42302185 0.39172849]
# Sortie prédite : [0.00977872 0.99999866 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [0.28742953 0.57774103]
# Sortie prédite : [0.01110388 0.9999987  1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [0.81411168 0.40549121]
# Sortie prédite : [0.00682964 0.99999865 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [0.53670007 0.75753682]
# Sortie prédite : [0.00865977 0.99999871 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [-0.51177761  0.11833726]
# Sortie prédite : [0.02322404 0.99999752 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [ 0.03006822 -0.96717019]
# Sortie prédite : [0.01227913 0.9999949  1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [ 0.18622445 -0.29342911]
# Sortie prédite : [0.0119052  0.99999783 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [0.26803664 0.15552462]
# Sortie prédite : [0.01130086 0.99999849 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [-0.32090587  0.67764253]
# Sortie prédite : [0.0201683  0.99999854 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [ 0.02982256 -0.26406127]
# Sortie prédite : [0.01355662 0.99999765 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [0.04939207 0.85149371]
# Sortie prédite : [0.01396622 0.99999872 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [-0.96645258  0.46130364]
# Sortie prédite : [0.03718542 0.99999742 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [0.47653592 0.55112934]
# Sortie prédite : [0.00924588 0.9999987  1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [-0.15754054  0.2219871 ]
# Sortie prédite : [0.01683987 0.99999824 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [ 0.48899143 -0.76989521]
# Sortie prédite : [0.00934245 0.99999713 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [0.86861728 0.37431126]
# Sortie prédite : [0.00653749 0.99999864 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.03454682 -0.12112856]
# Sortie prédite : [0.01453582 0.99999785 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.99276834 -0.08085978]
# Sortie prédite : [0.03227224 0.99999539 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [-0.28551069  0.39045894]
# Sortie prédite : [0.0193184  0.99999831 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [0.2993941  0.28859875]
# Sortie prédite : [0.01099313 0.99999859 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [ 0.37356584 -0.06728909]
# Sortie prédite : [0.01028374 0.99999835 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.03106985 -0.5365753 ]
# Sortie prédite : [0.01372885 0.99999672 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [0.57084174 0.58156746]
# Sortie prédite : [0.00843498 0.9999987  1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.54760685 -0.55141332]
# Sortie prédite : [0.01955119 0.99999474 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.22687603  0.70893749]
# Sortie prédite : [0.01837948 0.99999861 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [ 0.46770803 -0.03226905]
# Sortie prédite : [0.00949901 0.99999843 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.75082483  0.69821423]
# Sortie prédite : [0.03077883 0.99999818 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [ 0.28939012 -0.22966894]
# Sortie prédite : [0.01098883 0.99999807 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [ 0.41911691 -0.98355076]
# Sortie prédite : [0.00969224 0.99999616 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [-0.50648617 -0.78758997]
# Sortie prédite : [0.01746683 0.99999346 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [-0.96970036 -0.23991697]
# Sortie prédite : [0.02952466 0.99999464 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [0.49165148 0.5387625 ]
# Sortie prédite : [0.00911648 0.9999987  1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [0.62885437 0.55016201]
# Sortie prédite : [0.00799562 0.99999869 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.13638686 -0.31669644]
# Sortie prédite : [0.01542287 0.99999717 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [ 0.3669593  -0.32269078]
# Sortie prédite : [0.01030478 0.999998   1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [-0.74534384 -0.49334844]
# Sortie prédite : [0.02267885 0.99999415 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [0.9844309  0.44086925]
# Sortie prédite : [0.00588857 0.99999862 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [0.82856803 0.56932366]
# Sortie prédite : [0.00664395 0.99999866 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [ 0.73769059 -0.68175943]
# Sortie prédite : [0.00794514 0.99999769 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [ 0.18565401 -0.85766447]
# Sortie prédite : [0.01133495 0.99999605 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [0.8534765  0.18463365]
# Sortie prédite : [0.00677159 0.9999986  1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [ 0.40815132 -0.6696203 ]
# Sortie prédite : [0.00989546 0.99999728 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.56541193  0.32511685]
# Sortie prédite : [0.02524307 0.99999786 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [ 0.85617457 -0.29081882]
# Sortie prédite : [0.00714707 0.99999832 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [-0.46893982  0.54915294]
# Sortie prédite : [0.02333221 0.99999831 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.99765714  0.34601211]
# Sortie prédite : [0.03739934 0.99999704 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [-0.21796381 -0.52307826]
# Sortie prédite : [0.01576931 0.9999962  1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.33712639 -0.40736651]
# Sortie prédite : [0.01769853 0.99999628 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [0.35806152 0.98632981]
# Sortie prédite : [0.01025704 0.99999873 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [0.19081739 0.14383506]
# Sortie prédite : [0.01211587 0.99999844 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.24654669 -0.30500452]
# Sortie prédite : [0.01689342 0.99999693 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [-0.87939466  0.7286269 ]
# Sortie prédite : [0.03477855 0.99999806 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [ 0.79676033 -0.55692683]
# Sortie prédite : [0.00760293 0.99999796 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.87396864  0.87932466]
# Sortie prédite : [0.034187   0.99999825 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [-0.69488679 -0.87649546]
# Sortie prédite : [0.01861727 0.99999167 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [-0.77703623 -0.127166  ]
# Sortie prédite : [0.02707113 0.99999596 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [-0.57296796 -0.13399795]
# Sortie prédite : [0.02301163 0.99999659 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.65042991 -0.96554752]
# Sortie prédite : [0.01755068 0.9999912  1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [-0.4366503   0.67303364]
# Sortie prédite : [0.02260916 0.99999846 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [0.68606772 0.71531461]
# Sortie prédite : [0.00751135 0.99999869 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.94108456  0.21092062]
# Sortie prédite : [0.03453367 0.99999676 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.72814654 -0.40601088]
# Sortie prédite : [0.02330991 0.99999475 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [-0.70807028  0.180145  ]
# Sortie prédite : [0.02811542 0.99999725 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [ 0.68981913 -0.41946835]
# Sortie prédite : [0.00811254 0.99999811 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.57621393 -0.87312227]
# Sortie prédite : [0.01754504 0.99999243 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [-0.88657809 -0.46512202]
# Sortie prédite : [0.02507761 0.99999363 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.7927435   0.29490595]
# Sortie prédite : [0.03105501 0.99999737 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [0.8706863 0.1567586]
# Sortie prédite : [0.00670101 0.99999859 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [ 0.57481898 -0.92697077]
# Sortie prédite : [0.00882413 0.99999676 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [0.4957138  0.21134138]
# Sortie prédite : [0.00920039 0.9999986  1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [ 0.16137289 -0.44532518]
# Sortie prédite : [0.01200365 0.99999745 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.30871555 -0.52847678]
# Sortie prédite : [0.01679354 0.99999585 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [ 0.08012559 -0.71332023]
# Sortie prédite : [0.01237116 0.99999636 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [0.28836453 0.55265825]
# Sortie prédite : [0.01109685 0.99999869 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [ 0.8990336  -0.77353848]
# Sortie prédite : [0.00724398 0.99999763 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [-0.65535253  0.30430757]
# Sortie prédite : [0.02742107 0.99999766 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.62724249 -0.765815  ]
# Sortie prédite : [0.01881927 0.99999294 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [-0.27260831  0.98228662]
# Sortie prédite : [0.01892363 0.99999869 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [ 0.33947971 -0.9315532 ]
# Sortie prédite : [0.01021287 0.99999617 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [ 0.92238935 -0.2618539 ]
# Sortie prédite : [0.00680487 0.99999836 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [-0.66627254  0.23536899]
# Sortie prédite : [0.02738167 0.99999748 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [ 0.33584966 -0.28331321]
# Sortie prédite : [0.01056989 0.99999803 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [0.35627489 0.99346215]
# Sortie prédite : [0.01027269 0.99999873 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.07753738 -0.29907647]
# Sortie prédite : [0.01474218 0.99999736 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [ 0.06088448 -0.61247704]
# Sortie prédite : [0.012706  0.9999967 1.       ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [-0.93289674  0.24413259]
# Sortie prédite : [0.03461587 0.99999689 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.43035753  0.52194418]
# Sortie prédite : [0.02243915 0.99999832 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.4421895   0.83503018]
# Sortie prédite : [0.02257107 0.99999857 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [ 0.54272606 -0.83305359]
# Sortie prédite : [0.00901243 0.99999702 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [0.57070632 0.6523153 ]
# Sortie prédite : [0.00841025 0.99999871 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.83851294 -0.21603828]
# Sortie prédite : [0.02729753 0.99999531 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [ 0.89535456 -0.5921193 ]
# Sortie prédite : [0.00716316 0.99999796 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.90632425 -0.03205947]
# Sortie prédite : [0.03094756 0.99999593 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [-0.71363506 -0.58333335]
# Sortie prédite : [0.02137179 0.99999374 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [ 0.2802712  -0.40744291]
# Sortie prédite : [0.0109852  0.99999773 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [-0.14398822 -0.88788661]
# Sortie prédite : [0.01381045 0.99999462 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [-0.37354122 -0.9172778 ]
# Sortie prédite : [0.01554602 0.99999327 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.03778077  0.02382145]
# Sortie prédite : [0.01479187 0.99999809 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [-0.48738383  0.66582475]
# Sortie prédite : [0.02377472 0.99999841 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [ 0.71697981 -0.1489333 ]
# Sortie prédite : [0.00781512 0.99999842 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [-0.36395327  0.83063878]
# Sortie prédite : [0.02091972 0.9999986  1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [0.96362344 0.1896824 ]
# Sortie prédite : [0.00619709 0.99999859 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [-0.64952525  0.7111906 ]
# Sortie prédite : [0.02786374 0.99999831 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [ 0.83520454 -0.22294826]
# Sortie prédite : [0.00720358 0.99999838 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [ 0.39711135 -0.75460372]
# Sortie prédite : [0.00993616 0.999997   1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [0.40580848 0.2177894 ]
# Sortie prédite : [0.00997523 0.99999858 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [-0.7789192  -0.93083485]
# Sortie prédite : [0.01897366 0.99999063 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [ 0.98220581 -0.34011867]
# Sortie prédite : [0.00660488 0.9999983  1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [-0.52067885 -0.27414934]
# Sortie prédite : [0.0211384  0.99999621 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [-0.25563689  0.55835933]
# Sortie prédite : [0.01889895 0.9999985  1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [ 0.76087928 -0.58703299]
# Sortie prédite : [0.00779523 0.99999789 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.61429284 -0.92140321]
# Sortie prédite : [0.01754879 0.99999181 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [0.49687434 0.10132616]
# Sortie prédite : [0.00922921 0.99999854 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [0.69912212 0.2619096 ]
# Sortie prédite : [0.00765624 0.99999863 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [-0.40217099  0.89648075]
# Sortie prédite : [0.02160518 0.99999862 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [0.2946478  0.09196766]
# Sortie prédite : [0.01102453 0.99999845 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [ 0.64875467 -0.04708992]
# Sortie prédite : [0.00818635 0.99999848 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [ 0.71002331 -0.06441029]
# Sortie prédite : [0.00780423 0.99999848 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [ 0.54228979 -0.64121412]
# Sortie prédite : [0.00903019 0.99999756 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [ 0.5015183  -0.34547247]
# Sortie prédite : [0.0092922  0.99999809 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.86198357  0.61582425]
# Sortie prédite : [0.03424891 0.99999791 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.88082664 -0.45123723]
# Sortie prédite : [0.02515942 0.99999375 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [0.55012905 0.37995291]
# Sortie prédite : [0.00868738 0.99999867 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [-0.30203371 -0.36638006]
# Sortie prédite : [0.01741052 0.99999656 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.98474183 -0.02698297]
# Sortie prédite : [0.03283493 0.99999568 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [0.03459034 0.83831449]
# Sortie prédite : [0.01417722 0.99999872 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [-0.43847415 -0.55704511]
# Sortie prédite : [0.01818257 0.99999519 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [ 0.39009994 -0.06799671]
# Sortie prédite : [0.01014197 0.99999836 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.64615709 -0.24928174]
# Sortie prédite : [0.02343836 0.99999588 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [0.42891646 0.30527405]
# Sortie prédite : [0.00974731 0.99999863 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [0.33753452 0.44552757]
# Sortie prédite : [0.01059475 0.99999867 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [0.12916755 0.95819936]
# Sortie prédite : [0.012856   0.99999874 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [ 0.12107697 -0.54493556]
# Sortie prédite : [0.01225823 0.99999708 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [0.5647788  0.20258409]
# Sortie prédite : [0.00865496 0.9999986  1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.13991033 -0.83956318]
# Sortie prédite : [0.01393301 0.99999492 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [-0.90513596  0.03559279]
# Sortie prédite : [0.03172032 0.99999622 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [ 0.94475529 -0.35786059]
# Sortie prédite : [0.0067821  0.99999828 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [-0.86158899 -0.70206178]
# Sortie prédite : [0.02201236 0.99999204 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [-0.91341707  0.11798011]
# Sortie prédite : [0.03284161 0.99999651 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.8167419   0.85351005]
# Sortie prédite : [0.03245646 0.99999829 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [ 0.14761061 -0.03607089]
# Sortie prédite : [0.01249019 0.99999821 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [-0.43653101 -0.78008456]
# Sortie prédite : [0.01684357 0.99999388 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [ 0.77677051 -0.80116959]
# Sortie prédite : [0.00779142 0.99999745 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [0.56098624 0.66614078]
# Sortie prédite : [0.00848485 0.99999871 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [ 0.18755928 -0.84385865]
# Sortie prédite : [0.01133825 0.99999612 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.00670289  0.8769582 ]
# Sortie prédite : [0.01473978 0.99999872 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [ 0.32120657 -0.43300563]
# Sortie prédite : [0.01063556 0.99999773 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [-0.46474088  0.19695562]
# Sortie prédite : [0.02252431 0.99999778 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [ 0.02612654 -0.44055032]
# Sortie prédite : [0.01332556 0.99999718 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [ 0.87179055 -0.85780466]
# Sortie prédite : [0.00739396 0.99999741 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [ 8.62310902e-01 -1.98550332e-04]
# Sortie prédite : [0.00688075 0.99999853 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.5396118   0.20416334]
# Sortie prédite : [0.02420372 0.99999766 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [0.07734929 0.51283627]
# Sortie prédite : [0.01362673 0.99999863 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [0.34619212 0.86571608]
# Sortie prédite : [0.01041544 0.99999873 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.90519976 -0.26500899]
# Sortie prédite : [0.02794917 0.99999477 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.80043934 -0.21975692]
# Sortie prédite : [0.02653059 0.99999544 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [0.67283512 0.71523807]
# Sortie prédite : [0.00760629 0.99999869 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.13111401  0.5291123 ]
# Sortie prédite : [0.01670945 0.99999855 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [ 0.54677217 -0.17841229]
# Sortie prédite : [0.00894175 0.99999833 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [ 0.44244603 -0.04869272]
# Sortie prédite : [0.00970523 0.9999984  1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [ 0.28267108 -0.89736577]
# Sortie prédite : [0.01061289 0.99999616 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [0.83403557 0.15634196]
# Sortie prédite : [0.00690357 0.9999986  1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [ 0.39214714 -0.54725984]
# Sortie prédite : [0.01005    0.99999758 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [ 0.85928124 -0.3378798 ]
# Sortie prédite : [0.00716571 0.99999828 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [-0.73163399  0.59673044]
# Sortie prédite : [0.03023573 0.99999807 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [0.83041656 0.58700294]
# Sortie prédite : [0.00662384 0.99999866 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [-0.91846068  0.34740641]
# Sortie prédite : [0.03501534 0.99999723 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [-0.2919094  -0.73347202]
# Sortie prédite : [0.01569834 0.99999486 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [0.13673106 0.86717004]
# Sortie prédite : [0.01280978 0.99999873 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [0.08285438 0.44449933]
# Sortie prédite : [0.01353527 0.9999986  1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [ 0.27261959 -0.26672412]
# Sortie prédite : [0.01112258 0.99999799 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [-0.39173142 -0.6658876 ]
# Sortie prédite : [0.01703684 0.9999948  1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [-0.88853961 -0.9751978 ]
# Sortie prédite : [0.01965588 0.99998941 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [0.25915018 0.15264818]
# Sortie prédite : [0.01139142 0.99999848 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [-0.91448377 -0.92900024]
# Sortie prédite : [0.02033802 0.99998967 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.19722435 -0.50601821]
# Sortie prédite : [0.01559323 0.99999634 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [0.75615001 0.29791867]
# Sortie prédite : [0.00726055 0.99999864 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [ 0.55793267 -0.30264871]
# Sortie prédite : [0.00889705 0.99999819 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.67753947 -0.97561155]
# Sortie prédite : [0.01771132 0.99999093 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [-0.5051194   0.85737598]
# Sortie prédite : [0.02395758 0.99999854 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [ 0.29242318 -0.01861101]
# Sortie prédite : [0.01102525 0.99999834 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.53504682  0.98467467]
# Sortie prédite : [0.02432229 0.99999859 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [0.25639674 0.00213318]
# Sortie prédite : [0.01137999 0.99999834 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [ 0.54231768 -0.82726122]
# Sortie prédite : [0.00901547 0.99999704 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [ 0.93252076 -0.84223509]
# Sortie prédite : [0.0071437  0.99999751 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [ 0.76613215 -0.03852455]
# Sortie prédite : [0.0074482 0.9999985 1.       ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.16149801 -0.64283087]
# Sortie prédite : [0.0147631  0.99999586 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.30580584  0.12424318]
# Sortie prédite : [0.01917543 0.9999979  1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [ 0.84332583 -0.56714659]
# Sortie prédite : [0.00738456 0.99999798 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.49980253  0.96012905]
# Sortie prédite : [0.02358503 0.9999986  1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [ 0.40387418 -0.26367498]
# Sortie prédite : [0.01002042 0.99999813 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [-0.91821206  0.90338401]
# Sortie prédite : [0.0355468  0.99999823 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [ 0.74559968 -0.91581679]
# Sortie prédite : [0.00796598 0.99999709 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.18296985 -0.62166946]
# Sortie prédite : [0.01505016 0.99999588 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [ 0.29878069 -0.24511145]
# Sortie prédite : [0.01090004 0.99999805 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [0.32400112 0.04053211]
# Sortie prédite : [0.01073725 0.99999842 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [-0.82104623 -0.66210894]
# Sortie prédite : [0.02193447 0.99999259 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [-0.59239049  0.80117445]
# Sortie prédite : [0.02620892 0.99999844 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.09448198 -0.539228  ]
# Sortie prédite : [0.01437485 0.99999653 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.3989108  -0.46894628]
# Sortie prédite : [0.01819486 0.99999579 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [ 0.47973975 -0.03452396]
# Sortie prédite : [0.00940422 0.99999843 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [0.81756904 0.39154387]
# Sortie prédite : [0.00681861 0.99999865 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.94661438 -0.04559184]
# Sortie prédite : [0.03170199 0.99999573 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [0.1000098  0.20376012]
# Sortie prédite : [0.01320074 0.99999843 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.88503046  0.14033059]
# Sortie prédite : [0.032333   0.99999667 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.95643205  0.52891612]
# Sortie prédite : [0.03714748 0.99999759 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.67555442 -0.94943679]
# Sortie prédite : [0.01788499 0.99999117 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [0.19936883 0.39908419]
# Sortie prédite : [0.01209118 0.99999861 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [0.53279467 0.23016134]
# Sortie prédite : [0.00889239 0.99999861 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.94688137 -0.72627835]
# Sortie prédite : [0.02280132 0.9999913  1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [ 0.57258981 -0.0974376 ]
# Sortie prédite : [0.0087315  0.99999841 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [-0.8098374   0.10290037]
# Sortie prédite : [0.03006768 0.99999675 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.05916057 -0.45443376]
# Sortie prédite : [0.01419932 0.99999693 1.        ]
# ...
#
# Entrée : [-0.29892027 -0.03885739]
# Sortie prédite : [0.01858034 0.99999756 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [-0.54136932  0.04544027]
# Sortie prédite : [0.0234937  0.99999726 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [-0.10383733  0.26098305]
# Sortie prédite : [0.01604931 0.99999834 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.48830005  0.14345533]
# Sortie prédite : [0.02282904 0.99999762 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.28718488  0.78869158]
# Sortie prédite : [0.01945247 0.99999862 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [ 0.15629861 -0.12840865]
# Sortie prédite : [0.01233068 0.99999808 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [ 0.99285358 -0.81526449]
# Sortie prédite : [0.00690284 0.99999762 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [ 0.35818681 -0.3263324 ]
# Sortie prédite : [0.0103745  0.99999798 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [ 0.60401925 -0.60322508]
# Sortie prédite : [0.0086574  0.99999772 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [0.12408659 0.94691041]
# Sortie prédite : [0.01292718 0.99999874 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [-0.9494556   0.08552052]
# Sortie prédite : [0.03340261 0.99999628 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.33414863 -0.7160566 ]
# Sortie prédite : [0.01619091 0.99999477 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [-0.34653356 -0.77911466]
# Sortie prédite : [0.01600145 0.99999434 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [0.15738387 0.98488735]
# Sortie prédite : [0.01248936 0.99999874 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [-0.34464141 -0.47913193]
# Sortie prédite : [0.01745654 0.99999595 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [ 0.45082673 -0.53977187]
# Sortie prédite : [0.0096365  0.99999767 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [0.20932628 0.05068592]
# Sortie prédite : [0.01187813 0.99999836 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.46316577 -0.25584996]
# Sortie prédite : [0.0203263  0.99999647 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [ 0.16844978 -0.99456656]
# Sortie prédite : [0.01127108 0.9999953  1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [0.7618718 0.9900444]
# Sortie prédite : [0.00694914 0.99999865 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [0.58452292 0.48168158]
# Sortie prédite : [0.0083678  0.99999869 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [-0.47221949 -0.53598314]
# Sortie prédite : [0.01872249 0.99999516 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [0.92241756 0.61820185]
# Sortie prédite : [0.00609297 0.99999864 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [-0.59963376 -0.36952266]
# Sortie prédite : [0.02167459 0.99999549 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [-0.83466838 -0.50498546]
# Sortie prédite : [0.02383043 0.99999363 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [0.76957468 0.14607206]
# Sortie prédite : [0.00728886 0.99999859 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [ 0.60468742 -0.61998202]
# Sortie prédite : [0.00865531 0.99999768 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [0.13942679 0.04488307]
# Sortie prédite : [0.01263562 0.9999983  1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [0.53697449 0.65474967]
# Sortie prédite : [0.00868808 0.99999871 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [0.45234341 0.68665893]
# Sortie prédite : [0.00942513 0.99999872 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [ 0.52494512 -0.76009937]
# Sortie prédite : [0.00912585 0.99999722 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [ 0.56265946 -0.88166993]
# Sortie prédite : [0.00889467 0.9999969  1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [0.90103279 0.12985164]
# Sortie prédite : [0.00656394 0.99999858 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [-0.35822807  0.74796086]
# Sortie prédite : [0.02088698 0.99999856 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [0.54290975 0.13645114]
# Sortie prédite : [0.00885336 0.99999857 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.49706628 -0.76860747]
# Sortie prédite : [0.01749769 0.99999364 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [ 0.40328944 -0.76095029]
# Sortie prédite : [0.00989239 0.99999699 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [0.29892362 0.6073617 ]
# Sortie prédite : [0.01097539 0.9999987  1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [-0.34977369  0.78328861]
# Sortie prédite : [0.02068476 0.99999859 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [-0.14870284 -0.05378571]
# Sortie prédite : [0.01620344 0.9999978  1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.46931026  0.28687112]
# Sortie prédite : [0.02290063 0.99999794 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [-0.37287981 -0.29843787]
# Sortie prédite : [0.01871148 0.99999659 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.37829373 -0.12750809]
# Sortie prédite : [0.01957998 0.99999715 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [-0.89446658  0.06361039]
# Sortie prédite : [0.03177397 0.99999636 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.82979911 -0.3365048 ]
# Sortie prédite : [0.02571365 0.99999469 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [ 0.68947962 -0.1431928 ]
# Sortie prédite : [0.00797965 0.99999841 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [-0.34199158 -0.48909322]
# Sortie prédite : [0.01737591 0.99999591 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.98608381  0.64743352]
# Sortie prédite : [0.0384013  0.99999777 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.59466135  0.20114522]
# Sortie prédite : [0.02546791 0.99999755 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [0.95876547 0.97410846]
# Sortie prédite : [0.00582031 0.99999859 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.84299248  0.6878807 ]
# Sortie prédite : [0.03364059 0.99999805 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.55305225  0.00446087]
# Sortie prédite : [0.02350713 0.99999711 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [-0.19838499  0.83752204]
# Sortie prédite : [0.01779966 0.99999867 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [0.27738343 0.67585087]
# Sortie prédite : [0.01119835 0.99999872 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [-0.51870206 -0.51672542]
# Sortie prédite : [0.01943489 0.99999506 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.56626915  0.85099168]
# Sortie prédite : [0.02544436 0.9999985  1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [ 0.57378242 -0.4192481 ]
# Sortie prédite : [0.00881656 0.99999803 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [0.09373834 0.20310179]
# Sortie prédite : [0.01327735 0.99999843 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.61683365  0.71603862]
# Sortie prédite : [0.0269768  0.99999835 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [-0.0832381   0.06158226]
# Sortie prédite : [0.01547289 0.9999981  1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [-0.92877261  0.0179482 ]
# Sortie prédite : [0.03208272 0.99999607 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [ 0.85120493 -0.92472984]
# Sortie prédite : [0.00750506 0.99999721 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [-0.62546447  0.68076808]
# Sortie prédite : [0.02723905 0.9999983  1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [-0.97128766  0.30879855]
# Sortie prédite : [0.0362959  0.99999699 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [ 0.3934863  -0.72891802]
# Sortie prédite : [0.00997166 0.99999707 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.35418828  0.21791658]
# Sortie prédite : [0.02032333 0.99999799 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [0.3912778 0.4730721]
# Sortie prédite : [0.01005835 0.99999868 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [0.77137121 0.06095782]
# Sortie prédite : [0.00734276 0.99999856 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [0.39414347 0.57166873]
# Sortie prédite : [0.01000765 0.9999987  1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [ 0.09751203 -0.13957824]
# Sortie prédite : [0.01295283 0.999998   1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [ 0.2869342  -0.04976621]
# Sortie prédite : [0.01106959 0.99999831 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.04089062 -0.619841  ]
# Sortie prédite : [0.0136429  0.99999637 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.96847266 -0.39202935]
# Sortie prédite : [0.02736183 0.9999937  1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [ 0.69520717 -0.09968335]
# Sortie prédite : [0.00791833 0.99999845 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [-0.33317262  0.28336386]
# Sortie prédite : [0.02005974 0.99999812 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [ 0.74042863 -0.44302442]
# Sortie prédite : [0.00784086 0.9999981  1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.88185165  0.52524149]
# Sortie prédite : [0.03472875 0.99999772 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [0.62717409 0.58385419]
# Sortie prédite : [0.00799373 0.9999987  1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.88704828 -0.23907014]
# Sortie prédite : [0.02794152 0.99999499 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [0.50790132 0.67499525]
# Sortie prédite : [0.00893046 0.99999871 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [0.66605236 0.05851045]
# Sortie prédite : [0.00800922 0.99999855 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [ 0.13478496 -0.7837983 ]
# Sortie prédite : [0.01181834 0.99999622 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [0.89510016 0.08049833]
# Sortie prédite : [0.00663842 0.99999856 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [-0.83760233  0.42197375]
# Sortie prédite : [0.0330009  0.99999758 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [-0.38267061 -0.76678595]
# Sortie prédite : [0.01640476 0.99999424 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [0.63194217 0.94384775]
# Sortie prédite : [0.00786061 0.99999869 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [-0.39488745  0.24805596]
# Sortie prédite : [0.02121253 0.99999798 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [0.69017652 0.7227879 ]
# Sortie prédite : [0.00747978 0.99999869 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [0.74763121 0.90788455]
# Sortie prédite : [0.00704655 0.99999866 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [0.29566295 0.53508088]
# Sortie prédite : [0.01102035 0.99999869 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [-0.92344264  0.18250134]
# Sortie prédite : [0.03377052 0.99999671 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.25892915  0.82036813]
# Sortie prédite : [0.0188962  0.99999864 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [ 0.30905934 -0.7967654 ]
# Sortie prédite : [0.01051302 0.99999665 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [-0.93507924 -0.73837104]
# Sortie prédite : [0.02251869 0.99999127 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [0.03989865 0.04934573]
# Sortie prédite : [0.01381879 0.99999822 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [0.9350074  0.79582773]
# Sortie prédite : [0.0059614  0.99999862 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.50454784  0.67004152]
# Sortie prédite : [0.02417984 0.9999984  1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [-0.27587414 -0.46438716]
# Sortie prédite : [0.0166734  0.99999625 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.17088516 -0.66055862]
# Sortie prédite : [0.01479855 0.99999574 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [ 0.71793122 -0.59244243]
# Sortie prédite : [0.00801943 0.99999785 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [-0.22922405  0.0181291 ]
# Sortie prédite : [0.01759799 0.99999781 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [-0.58000835 -0.50861653]
# Sortie prédite : [0.02028941 0.99999484 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [ 0.9825646  -0.74027146]
# Sortie prédite : [0.00689659 0.99999776 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [ 0.69593406 -0.12487483]
# Sortie prédite : [0.00792895 0.99999843 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [ 0.84886928 -0.29422802]
# Sortie prédite : [0.00718614 0.99999832 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [-0.62568647  0.12556969]
# Sortie prédite : [0.02580063 0.99999729 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [-0.62954069  0.75024417]
# Sortie prédite : [0.0272715  0.99999837 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [0.75641231 0.45161629]
# Sortie prédite : [0.00715771 0.99999867 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [0.44028725 0.18730077]
# Sortie prédite : [0.00967646 0.99999857 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [-0.27351206  0.77935687]
# Sortie prédite : [0.01920155 0.99999862 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [0.27571373 0.23859782]
# Sortie prédite : [0.01123367 0.99999855 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [0.02369862 0.82039799]
# Sortie prédite : [0.01433812 0.99999872 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [-0.41898611 -0.55088722]
# Sortie prédite : [0.01798569 0.99999531 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [ 0.70057452 -0.93388495]
# Sortie prédite : [0.0081821  0.99999697 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [0.26751502 0.89305999]
# Sortie prédite : [0.0112489  0.99999874 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [0.12323879 0.76847937]
# Sortie prédite : [0.01301761 0.99999872 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [-0.32135467 -0.04412203]
# Sortie prédite : [0.0189399  0.99999751 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [-0.27089225  0.79256189]
# Sortie prédite : [0.01914225 0.99999863 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [-0.78128074 -0.99056694]
# Sortie prédite : [0.01851283 0.99999006 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.1082863   0.92696989]
# Sortie prédite : [0.01622707 0.99999871 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [0.39213359 0.35710284]
# Sortie prédite : [0.01007482 0.99999864 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [ 0.27048878 -0.76460053]
# Sortie prédite : [0.01081332 0.99999668 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [-0.16270085  0.24863579]
# Sortie prédite : [0.01696198 0.99999827 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [-0.22180213  0.19053164]
# Sortie prédite : [0.01784926 0.99999812 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [0.14535087 0.49669355]
# Sortie prédite : [0.01275234 0.99999864 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [-0.24577246  0.18415132]
# Sortie prédite : [0.01824894 0.99999808 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [-0.93789051 -0.2240888 ]
# Sortie prédite : [0.02912181 0.99999486 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [ 0.19295391 -0.57941176]
# Sortie prédite : [0.01159148 0.99999713 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [-0.50791334  0.20661584]
# Sortie prédite : [0.02350011 0.99999772 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [ 0.61132871 -0.60295474]
# Sortie prédite : [0.00861454 0.99999773 1.        ]
# Sortie attendue : [1. 0. 0.]
#
# Entrée : [0.66932108 0.65669961]
# Sortie prédite : [0.00765226 0.99999869 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [0.12981468 0.64932631]
# Sortie prédite : [0.01295388 0.99999869 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [ 0.38744529 -0.92564766]
# Sortie prédite : [0.00991403 0.99999633 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [-0.5924326  0.9189611]
# Sortie prédite : [0.02591841 0.99999852 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.77999662  0.51236088]
# Sortie prédite : [0.0315599  0.99999786 1.        ]
# Sortie attendue : [0. 0. 1.]
#
# Entrée : [-0.64475725  0.67170996]
# Sortie prédite : [0.02776717 0.99999827 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Entrée : [ 0.43775832 -0.78909305]
# Sortie prédite : [0.00965783 0.99999697 1.        ]
# Sortie attendue : [0. 1. 0.]
#
# Taux de réussite : 46.40%
# 1

# %% [markdown]
# # BETA SVM

# %% [markdown]
# tentative de TEST SVM

# %%
import ctypes
import numpy as np
import os
import sys
import matplotlib.pyplot as plt

# Get the directory of the current script
current_dir = os.getcwd()

# Append the path to the DLL to the system's search path
dll_path = os.path.join(current_dir, 'SVM.dll')
sys.path.append(dll_path)

# Load the DLL
svm_lib = ctypes.cdll.LoadLibrary(dll_path)

# Définition des types de données pour les fonctions de la DLL
svm_lib.trainSVM.argtypes = [
    np.ctypeslib.ndpointer(dtype=np.float64, ndim=2, flags="C_CONTIGUOUS"),
    ctypes.c_size_t,
    ctypes.c_size_t,
    np.ctypeslib.ndpointer(dtype=np.float64, ndim=1, flags="C_CONTIGUOUS"),
    ctypes.POINTER(ctypes.c_double),
    ctypes.c_int
]
svm_lib.trainSVM.restype = None

svm_lib.predictSVM.argtypes = [
    np.ctypeslib.ndpointer(dtype=np.float64, ndim=1, flags="C_CONTIGUOUS"),
    np.ctypeslib.ndpointer(dtype=np.float64, ndim=1, flags="C_CONTIGUOUS"),
    ctypes.c_double,
    ctypes.c_size_t
]
svm_lib.predictSVM.restype = ctypes.c_int

# Fonction pour entraîner le SVM avec l'algorithme du perceptron
def trainSVM(trainingData, numIterations):
    features = trainingData[:, :-1].astype(np.float64)
    labels = trainingData[:, -1].astype(np.float64)

    # Initialiser les poids et le biais à zéro
    weights = np.zeros(features.shape[1], dtype=np.float64)
    bias = ctypes.c_double(0.0)

    svm_lib.trainSVM(features, features.shape[0], features.shape[1], weights, ctypes.byref(bias), numIterations)

    return weights, bias.value

# Fonction pour prédire la classe d'un exemple avec le SVM entraîné
def predictSVM(features, weights, bias):
    features = [float(x) for x in features]
    return svm_lib.predictSVM(np.array(features, dtype=np.float64), weights, bias, len(features))


trainingData = np.array([
     [1, 1,1],
      [2, 3,-1],
      [3, 3,-1]
])

# Entraînement du SVM
numIterations = 1000
weights, bias = trainSVM(trainingData, numIterations)

# Création des données de test
testData = np.array([
    [-1.5, -1.5],
    [1.5, 1.5]
])

# Affichage des prédictions pour les données de test
for i in range(testData.shape[0]):
    features = testData[i]
    prediction = predictSVM(features, weights, bias)
    print(f"Features: {features[0]}, {features[1]} => Output: {prediction}")

# Tracer les données d'entraînement
plt.scatter(trainingData[:, 0], trainingData[:, 1], c=trainingData[:, 2], cmap='bwr')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('Training Data')

# Tracer les frontières de décision du SVM
x_min, x_max = plt.xlim()
y_min, y_max = plt.ylim()
xx, yy = np.meshgrid(np.linspace(x_min, x_max, 100), np.linspace(y_min, y_max, 100))
Z = np.array([predictSVM([float(x), float(y)], weights, bias) for x, y in zip(xx.ravel(), yy.ravel())], dtype=np.float64)
Z = Z.reshape(xx.shape)
plt.contour(xx, yy, Z, colors='black', linewidths=1)
plt.show()
